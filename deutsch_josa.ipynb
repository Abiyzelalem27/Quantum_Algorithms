# %% [markdown]
# ### The Deutsch-Jozsa algorithm
#
# Implement the $U_f$ gate for a general black box (or oracle) function $f: \{0,1\}^n \rightarrow \{0,1\}$. We don't want to simulate the auxiliary qubit explicitly, so the action of the $U_f$ gate is an added phase $(-1)^{f(x)}$ on each basis state x. Let's be super clear on what we mean by this: The computational basis consists of $2^n$ states: $\{|00..0\rangle, |00..01\rangle.., |11..1\rangle  \}$. The bitstring $x$ that enters into the black box function is the binary array of length $n$ that describes the state of each qubit for a given basis state. We can also enumerate  the basis states with the integer numbers $x$ running from $0$ to $2^n-1$. Now the bitstring $x$ is simply the list of binary digits of the integer number $x$. This identification of the "index" of the basis state with the corresponding "state" of the qubits will also be crucial for the other quantum algorithms like the quantum Fourier transform.
#
# np.abs() mean (take the absolute value (the magnitude) of each number in an array)

# %%
import sys
sys.path.append("src")

import numpy as np
from collections import Counter
import quantum_algorithms as qa # customers package 

# %matplotlib inline

# %%
n = 2

state_c = qa.deutsch_jozsa(n, f_constant_0)
state_b = qa.deutsch_jozsa(n, f_balanced_parity)
probs_c = qa.measure_probs_first_n(state_c, n)
probs_b = qa.measure_probs_first_n(state_b, n)

print("P(0) constant=", probs_c[0])
print("P(0) balanced=", probs_b[0])

# %%
probs_b

# %%
probs_c

# %%
n = 1

state_const = qa.deutsch_jozsa(n, f_constant_0)
state_bal = qa.deutsch_jozsa(n, f_balanced_parity)

probs_const = qa.measure_probs_first_n(state_const, n)
probs_bal = qa.measure_probs_first_n(state_bal, n)
print("P(0) constant =", probs_const[0])
print("P(0) balanced =", probs_bal[0])

# %%
probs_c

# %%
probs_b

# %%
# Measure both cases
shots = 1024
n = 9

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b = qa.deutsch_jozsa(n, f_balanced_parity)
samples_c = qa.sample_measurements_input(state_c, n, shots)
samples_b  = qa.sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print(" state balanced:\n", state_b)
print("Measurement samples (constant):\n", samples_c)
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 2000
n = 11

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)
samples_c = qa.sample_measurements_input(state_c, n, shots)
samples_b  = qa.sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 3000
n = 7

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)
samples_c = qa.sample_measurements_input(state_c, n, shots)
samples_b  = qa.sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 7000
n = 6 

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)

samples_c = qa.sample_measurements_input(state_c, n, shots)
samples_b  = qa.sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 10000
n = 7

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)

samples_c = qa.sample_measurements_input(state_c, n, shots)
samples_b  = qa.sample_measurements_input(state_b, n, shots)

print("state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 10000
n = 6

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)

samples_c = qa.sample_measurements_input(state_c, n, shots)
samples_b  = qa.sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 20000
n = 2

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)

samples_c = qa.sample_measurements_input(state_c, n, shots)
samples_b  = qa.sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 20000
n = 2

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)

samples_c = sample_measurements_input(state_c, n, shots)
samples_b  = sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 20000
n = 3

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)
samples_c = sample_measurements_input(state_c, n, shots)
samples_b  = sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 20000
n = 4

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)
samples_c = sample_measurements_input(state_c, n, shots)
samples_b  = sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 20000
n = 5

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)
samples_c = sample_measurements_input(state_c, n, shots)
samples_b  = sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)

# %%
shots = 20000
n = 10

state_c = qa.deutsch_jozsa(n, f_constant_1)
state_b  = qa.deutsch_jozsa(n, f_balanced_parity)

samples_c = sample_measurements_input(state_c, n, shots)
samples_b  = sample_measurements_input(state_b, n, shots)

print(" state constant:\n", state_c)
print()
print(" state balanced:\n", state_b)
print()
print("Measurement samples (constant):\n", samples_c)
print()
print("Measurement samples (balanced):\n", samples_b)
